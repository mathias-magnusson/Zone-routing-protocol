# %%
# Imports
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import csv

# %%
import pandas as pd

filepath_1 = "/Users/mathiasmagnusson/Zone-routing-protocol/Data-out/iarp-test-1.csv"
filepath_2 = "/Users/mathiasmagnusson/Zone-routing-protocol/Data-out/iarp-test-2.csv"
filepath_3 = "/Users/mathiasmagnusson/Zone-routing-protocol/Data-out/iarp-test-3.csv"
filepath_4 = "/Users/mathiasmagnusson/Zone-routing-protocol/Data-out/iarp-test-only-0.csv"

df1 = pd.read_csv(filepath_1)
df2 = pd.read_csv(filepath_2)
df3 = pd.read_csv(filepath_3)
df4 = pd.read_csv(filepath_4)
df1 = df1.T
df2 = df2.T
df3 = df3.T
df4 = df4.T
df1.columns = ["$\u03C1$ = 1"]
df2.columns = ["$\u03C1$ = 2"]
df3.columns = ["$\u03C1$ = 3"]
df4.columns = ["$\u03C1$ = 2"]

# %%
## IARP RUNNING TIMES OF p = 1,2,3,4,5

plt.style.use('seaborn-v0_8')

_, ax = plt.subplots(figsize=(20,6))
df1.plot(ax=ax, linewidth=4)
df2.plot(ax=ax, linewidth=4)
df3.plot(ax=ax, linewidth=3)
#df4.plot(ax=ax, linewidth=3)

ax.set_yscale('log')

#ax.vlines(range(0, 450, 100), 0, 10000, colors="tab:gray", label='Orbit period')
ax.set_ylabel("# Packets", weight="bold", fontsize=20)
ax.set_xlabel("Time stamp (minutes)", weight="bold", fontsize=20)
plt.title("IARP packets for all nodes", weight="bold", fontsize=18)
plt.ylim(500,150000)
plt.xlim(0,100)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)

legend = plt.legend(loc='upper right', bbox_to_anchor=(0.98, 0.98), frameon=True, framealpha=1, facecolor='white', fontsize = 14)

# %%
## IARP RUNNING TIME AT p = 2

plt.style.use('seaborn-v0_8')

_, ax = plt.subplots(figsize=(20,6))
df4.plot(ax=ax, linewidth=3)

ax.vlines(range(0, 450, 100), 0, 300, colors="tab:gray", label='Orbit period')
ax.set_ylabel("# Packets", weight="bold", fontsize=20)
ax.set_xlabel("Time stamp (seconds)", weight="bold", fontsize=20)
plt.title("IARP packets for node 0", weight="bold", fontsize=18)
plt.ylim(0,300)
plt.xlim(0,200)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)

legend = plt.legend(loc='upper right', bbox_to_anchor=(0.98, 0.98), frameon=True, framealpha=1, facecolor='white', fontsize = 14)

# %%
## IARP RUNNING TIME AS A FUNCTION OF ZONE RADII
import seaborn as sns

running_times_min = [2.39, 22.19, 245.80, 3474, 50499.8]
running_times_max = [6.79, 145.6, 2386.80, 33821.19, 431215]
p_values = [1, 2, 3, 4, 5]

plt.style.use('seaborn-v0_8')

plt.plot(p_values, running_times_min, marker='o', linestyle='-', color='tab:blue', label='min')
plt.plot(p_values, running_times_max, marker='o', linestyle='-', color='tab:red', label='max')

plt.yscale('log')
plt.xticks([1, 2, 3, 4, 5], fontsize=12)
plt.yticks(fontsize=12)

plt.xlabel('$\u03C1$', weight='bold', fontsize=12)
plt.ylabel('Simulation units', weight='bold', fontsize=12)
plt.title('Minimum and maximum running times for IARP', weight='bold')
legend = plt.legend(loc='lower right', bbox_to_anchor=(0.98, 0.02), frameon=True, framealpha=1, facecolor='white', fontsize = 14)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [19], line 2
#       1 ## IARP RUNNING TIME AS A FUNCTION OF ZONE RADII
# ----> 2 import seaborn as sns
#       4 running_times_min = [2.39, 22.19, 245.80, 3474, 50499.8]
#       5 running_times_max = [6.79, 145.6, 2386.80, 33821.19, 431215]
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
## TESTING FOR IARP. X-VALUES ARE P, Y-VALUES ARE PACKETS, AND 5 DIFFERENT GRAPHS ARE NODE POPULATION

zone_radius = [1,2,3,4]
y_18 = [84, 375, 979, 1541]
y_30 = [260, 1858, 10410, 45202]
y_42 = [556, 5786,49690, 367498]
y_54 = [1008, 14562, 177310, 1926590]
y_66 = [1420, 24932, 380736, 5255952]

# set width of bar 
barWidth = 0.15

# Set position of bar on X axis 
br1 = np.arange(len(y_18))
br2 = [x + barWidth for x in br1] 
br3 = [x + barWidth for x in br2]
br4 = [x + barWidth for x in br3] 
br5 = [x + barWidth for x in br4]

plt.style.use('seaborn-v0_8')

# Make the plot
plt.bar(br1, y_18, color='tab:blue', width = barWidth, edgecolor ='grey', label ='N = 18') 
plt.bar(br2, y_30, color='tab:green', width = barWidth, edgecolor ='grey', label ='N = 30') 
plt.bar(br3, y_42, color='tab:red', width = barWidth, edgecolor ='grey', label ='N = 42') 
plt.bar(br4, y_54, color='tab:purple', width = barWidth, edgecolor ='grey', label ='N = 54') 
plt.bar(br5, y_66, color='tab:orange', width = barWidth, edgecolor ='grey', label ='N = 66')

plt.yscale('log')
plt.xticks([r + barWidth for r in range(len(y_18))], [1,2,3,4], fontsize=18)
plt.yticks(fontsize=18)
plt.xlabel('$\u03C1$', weight='bold', fontsize=18)
plt.ylabel("Packets", weight='bold', fontsize=18)
plt.title("IARP packets at altitude 718km", weight='bold', fontsize=14)

legend = plt.legend(loc='upper left', bbox_to_anchor=(0.02, 0.98), frameon=True, framealpha=1, facecolor='white', fontsize = 14)

# %%
## TESTING FOR IERP. X-VALUES ARE P, Y-VALUES ARE PACKETS, AND 5 DIFFERENT GRAPHS ARE NODE POPULATION

zone_radius = [1,2,3,4]
y_18 = [8.4, 2.4, 1, 0]
y_30 = [150.8, 90.4, 59.4, 12]
y_42 = [9142, 934.6, 177.6, 21]
y_54 = [98528, 1208, 67.8, 12]
y_66 = [160593, 3114, 255.2, 36]

# set width of bar 
barWidth = 0.15

# Set position of bar on X axis 
br1 = np.arange(len(y_18))
br2 = [x + barWidth for x in br1] 
br3 = [x + barWidth for x in br2]
br4 = [x + barWidth for x in br3] 
br5 = [x + barWidth for x in br4]

plt.style.use('seaborn-v0_8')

# Make the plot
plt.bar(br1, y_18, color='tab:blue', width = barWidth, edgecolor ='grey', label ='N = 18') 
plt.bar(br2, y_30, color='tab:green', width = barWidth, edgecolor ='grey', label ='N = 30') 
plt.bar(br3, y_42, color='tab:red', width = barWidth, edgecolor ='grey', label ='N = 42') 
plt.bar(br4, y_54, color='tab:purple', width = barWidth, edgecolor ='grey', label ='N = 54') 
plt.bar(br5, y_66, color='tab:orange', width = barWidth, edgecolor ='grey', label ='N = 66')

plt.yscale('log')
plt.xticks([r + barWidth for r in range(len(y_18))], [1,2,3,4], fontsize=18)
plt.yticks(fontsize=18)
plt.ylim()
plt.xlabel('$\u03C1$', weight='bold', fontsize=18)
plt.ylabel("Packets", weight='bold', fontsize=18)
plt.title("IERP packets at altitude 718km", weight='bold', fontsize=14)

legend = plt.legend(loc='upper right', bbox_to_anchor=(0.98, 0.98), frameon=True, framealpha=1, facecolor='white', fontsize = 14)

# %%
## TESTING FOR IARP. X-VALUES ARE P, Y-VALUES ARE PACKETS, AND DIFFERENT ALTITUDES


zone_radius = [1,2,3,4]
y_518 = [1176, 16650, 203990, 2266834]
y_618 = [1272, 19542, 259706, 3130430]
y_718 = [1420, 24932, 380736, 5255952]
y_818 = [1532, 28582, 460590, 6703796]
y_918 = [1696, 35258, 631974, 10208882]

# set width of bar 
barWidth = 0.15

# Set position of bar on X axis 
br1 = np.arange(len(y_518))
br2 = [x + barWidth for x in br1] 
br3 = [x + barWidth for x in br2]
br4 = [x + barWidth for x in br3] 
br5 = [x + barWidth for x in br4]

plt.style.use('seaborn-v0_8')

# Make the plot
plt.bar(br1, y_518, color='tab:blue', width = barWidth, edgecolor ='grey', label ='h = 18') 
plt.bar(br2, y_618, color='tab:green', width = barWidth, edgecolor ='grey', label ='h = 30') 
plt.bar(br3, y_718, color='tab:red', width = barWidth, edgecolor ='grey', label ='h = 42') 
plt.bar(br4, y_818, color='tab:purple', width = barWidth, edgecolor ='grey', label ='h = 54') 
plt.bar(br5, y_918, color='tab:orange', width = barWidth, edgecolor ='grey', label ='h = 66')

plt.yscale('log')
plt.xticks([r + barWidth for r in range(len(y_518))], [1,2,3,4], fontsize=18)
plt.yticks(fontsize=18)
plt.xlabel('$\u03C1$', weight='bold', fontsize=18)
plt.ylabel("Packets", weight='bold', fontsize=18)
plt.title("IARP packets at different altitudes with N = 66", weight='bold', fontsize=14)

legend = plt.legend(loc='upper left', bbox_to_anchor=(0.02, 0.98), frameon=True, framealpha=1, facecolor='white', fontsize = 14)

# %%
## TESTING FOR IERP. X-VALUES ARE P, Y-VALUES ARE PACKETS, AND DIFFERENT ALTITUDES


zone_radius = [1,2,3,4]
y_518 = [142493, 12360, 1332, 55]
y_618 = [171547, 5962, 711.2, 36]
y_718 = [160593, 3114, 255, 36]
y_818 = [221642, 1615, 92, 44]
y_918 = [262047, 1355, 85, 31]

# set width of bar 
barWidth = 0.15

# Set position of bar on X axis 
br1 = np.arange(len(y_518))
br2 = [x + barWidth for x in br1] 
br3 = [x + barWidth for x in br2]
br4 = [x + barWidth for x in br3] 
br5 = [x + barWidth for x in br4]

plt.style.use('seaborn-v0_8')

# Make the plot
plt.bar(br1, y_518, color='tab:blue', width = barWidth, edgecolor ='grey', label ='h = 18') 
plt.bar(br2, y_618, color='tab:green', width = barWidth, edgecolor ='grey', label ='h = 30') 
plt.bar(br3, y_718, color='tab:red', width = barWidth, edgecolor ='grey', label ='h = 42') 
plt.bar(br4, y_818, color='tab:purple', width = barWidth, edgecolor ='grey', label ='h = 54') 
plt.bar(br5, y_918, color='tab:orange', width = barWidth, edgecolor ='grey', label ='h = 66')

plt.yscale('log')
plt.xticks([r + barWidth for r in range(len(y_518))], [1,2,3,4], fontsize=18)
plt.yticks(fontsize=18)
plt.xlabel('$\u03C1$', weight='bold', fontsize=18)
plt.ylabel("Packets", weight='bold', fontsize=18)
plt.title("IERP packets at different altitudes with N = 66", weight='bold', fontsize=14)

legend = plt.legend(loc='upper right', bbox_to_anchor=(0.98, 0.98), frameon=True, framealpha=1, facecolor='white', fontsize = 14)

# %%
zone_radius = (
    "1",
    "2",
    "3",
    "4",
)

data = {
    "IERP": np.array([99, 51, 1, 0]),
    "IARP": np.array([1, 49, 99, 100]),
}

# set width of bar 
barWidth = 0.25

plt.style.use('seaborn-v0_8')

fig, ax = plt.subplots()
bottom = np.zeros(4)

for boolean, data in data.items():
    p = ax.bar(zone_radius, data, barWidth, label=boolean, bottom=bottom)
    bottom += data

plt.ylim(top=130)
plt.yticks(fontsize=18)
plt.xlabel('$\u03C1$', weight='bold', fontsize=18)
plt.ylabel("Percentage (%)", weight='bold', fontsize=18)
plt.title("Percentage distribution of IARP and IERP", weight='bold', fontsize=14)

legend = plt.legend(loc='upper right', bbox_to_anchor=(0.98, 0.98), frameon=True, framealpha=1, facecolor='white', fontsize = 14)

plt.show()

# %%
# Distribution of IARP and IERP for zone radius = 1

zone_radius = (
    "18",
    "30",
    "42",
    "54",
    "66"
)

data = {
    "IERP": np.array([81, 63, 99, 100, 100]),
    "IARP": np.array([19, 37, 1, 0, 0]),
}

# set width of bar 
barWidth = 0.25

plt.style.use('seaborn-v0_8')

fig, ax = plt.subplots()
bottom = np.zeros(5)

for boolean, data in data.items():
    p = ax.bar(zone_radius, data, barWidth, label=boolean, bottom=bottom)
    bottom += data

plt.ylim(top=130)
plt.yticks(fontsize=18)
plt.xlabel('Node population', weight='bold', fontsize=18)
plt.ylabel("Percentage (%)", weight='bold', fontsize=18)
plt.title("Percentage distribution of IARP and IERP", weight='bold', fontsize=14)

legend = plt.legend(loc='upper right', bbox_to_anchor=(0.98, 0.98), frameon=True, framealpha=1, facecolor='white', fontsize = 14)

plt.show()

# %%
# Distribution of IARP and IERP for zone radius = 2

zone_radius = (
    "18",
    "30",
    "42",
    "54",
    "66"
)

data = {
    "IERP": np.array([0.6, 4.6, 14, 8, 11]),
    "IARP": np.array([99.4, 95.4, 86, 92, 89]),
}

# set width of bar 
barWidth = 0.25

plt.style.use('seaborn-v0_8')

fig, ax = plt.subplots()
bottom = np.zeros(5)

for boolean, data in data.items():
    p = ax.bar(zone_radius, data, barWidth, label=boolean, bottom=bottom)
    bottom += data

plt.ylim(top=130)
plt.yticks(fontsize=18)
plt.xlabel('$\u03C1$', weight='bold', fontsize=18)
plt.ylabel("Percentage (%)", weight='bold', fontsize=18)
plt.title("Percentage distribution of IARP and IERP", weight='bold', fontsize=14)

legend = plt.legend(loc='upper right', bbox_to_anchor=(0.98, 0.98), frameon=True, framealpha=1, facecolor='white', fontsize = 14)

plt.show()

# %%
# Number of neighbours with 66 nodes and differnet altitudes:

zone_radius = [1,2,3,4]
y_518 = [588, 1488, 2516, 3496]
y_618 = [636, 1580, 2632, 3610]
y_718 = [710, 1700, 2782, 3750]
y_818 = [766, 1826, 2926, 3914]
y_918 = [848, 1986, 3140, 4150]

plt.style.use('seaborn-v0_8')

plt.plot(zone_radius, y_518, marker='o', linestyle='-', label='h = 518')
plt.plot(zone_radius, y_618, marker='o', linestyle='-', label='h = 618')
plt.plot(zone_radius, y_718, marker='o', linestyle='-', label='h = 718')
plt.plot(zone_radius, y_818, marker='o', linestyle='-', label='h = 818')
plt.plot(zone_radius, y_918, marker='o', linestyle='-', label='h = 918')

#plt.yscale('log')
plt.xticks([1,2,3,4], fontsize=18)
plt.yticks(fontsize=18)
plt.xlabel('$\u03C1$', weight='bold', fontsize=18)
plt.ylabel("Neihgbours", weight='bold', fontsize=18)
plt.title("No. of neighbours for different altitudes with N = 66", weight='bold', fontsize=14)

legend = plt.legend(loc='center right', bbox_to_anchor=(1, 0.5), frameon=True, framealpha=1, facecolor='white', fontsize = 14)

# %%
# walkerStar vs. walkerDelta IARP

zone_radius = [1,2,3,4]
walkerStar_IARP = [1420, 24932, 380736, 5255952]
walkerDelta_IARP = [1184, 14812, 147028, 1304636]

# set width of bar 
barWidth = 0.15

# Set position of bar on X axis 
br1 = np.arange(len(y_18))
br2 = [x + barWidth for x in br1] 

plt.style.use('seaborn-v0_8')

# Make the plot
plt.bar(br1, walkerStar_IARP, color='tab:orange', width = barWidth, edgecolor ='grey', label ='Walker Star') 
plt.bar(br2, walkerDelta_IARP, color='tab:purple', width = barWidth, edgecolor ='grey', label ='Walker Delta') 

plt.yscale('log')
plt.xticks([r + barWidth for r in range(len(y_18))], [1,2,3,4], fontsize=18)
plt.yticks(fontsize=18)
plt.xlabel('$\u03C1$', weight='bold', fontsize=18)
plt.ylabel("Packets", weight='bold', fontsize=18)
plt.title("IARP packets Walker Star vs. Walker Delta with N = 66", weight='bold', fontsize=14)

legend = plt.legend(loc='upper left', bbox_to_anchor=(0.02, 0.98), frameon=True, framealpha=1, facecolor='white', fontsize = 14)

# %%
# walkerStar vs. walkerDelta IERP
zone_radius = [1,2,3,4]
walkerStar_IERP = [160593, 3114, 255, 32]
walkerDelta_IERP = [606899, 13619, 347, 36]

# set width of bar 
barWidth = 0.15

# Set position of bar on X axis 
br1 = np.arange(len(y_18))
br2 = [x + barWidth for x in br1] 

plt.style.use('seaborn-v0_8')

# Make the plot
plt.bar(br1, walkerStar_IERP, color='tab:orange', width = barWidth, edgecolor ='grey', label ='Walker Star') 
plt.bar(br2, walkerDelta_IERP, color='tab:purple', width = barWidth, edgecolor ='grey', label ='Walker Delta') 

plt.yscale('log')
plt.xticks([r + barWidth for r in range(len(y_18))], [1,2,3,4], fontsize=18)
plt.yticks(fontsize=18)
plt.xlabel('$\u03C1$', weight='bold', fontsize=18)
plt.ylabel("Packets", weight='bold', fontsize=18)
plt.title("IERP packets Walker Star vs. Walker Delta with N = 66", weight='bold', fontsize=14)

legend = plt.legend(loc='upper right', bbox_to_anchor=(0.98, 0.98), frameon=True, framealpha=1, facecolor='white', fontsize = 14)

# %%
# Time used to find routes IARP and IERP combined

zone_radius = [1,2,3,4]
walkerStar_combined = [31.44, 0.62, 6.43, 95.39]
walkerDelta_combined = [153.25, 1.44, 2.91, 27.4]

# set width of bar 
barWidth = 0.15

# Set position of bar on X axis 
br1 = np.arange(len(walkerStar_combined))
br2 = [x + barWidth for x in br1] 

plt.style.use('seaborn-v0_8')

# Make the plot
plt.bar(br1, walkerStar_combined, color='tab:orange', width = barWidth, edgecolor ='grey', label ='Walker Star') 
plt.bar(br2, walkerDelta_combined, color='tab:purple', width = barWidth, edgecolor ='grey', label ='Walker Delta')

#plt.yscale('log')
plt.xticks([r + barWidth for r in range(len(y_18))], [1,2,3,4], fontsize=18)
plt.yticks(fontsize=18)
plt.xlabel('$\u03C1$', weight='bold', fontsize=18)
plt.ylabel("Time (s)", weight='bold', fontsize=18)
plt.title("Combined IARP and IERP time with N = 66", weight='bold', fontsize=14)

legend = plt.legend(loc='upper right', frameon=True, framealpha=1, facecolor='white', fontsize = 14)

# %%
# Time used to find routes IARP and IERP combined

zone_radius = [1,2,3,4]
N_18_combined = [75.6, 372.6, 979, 1541]
N_30_combined = [110, 1768, 10350, 45190]
N_42_combined = [8586, 4851, 49512, 367468]
N_54_combined = [97520, 13354, 177242, 1926578]
N_66_combined = [159174, 21818, 380481, 5255916]
N_78_combined = [1270058, 5785, 783169, 13397892]
N_90_combined = [6057385, 41556, 1373271, 27064468]

# set width of bar 
barWidth = 0.10

# Set position of bar on X axis 
br1 = np.arange(len(N_18_combined))
br2 = [x + barWidth for x in br1] 
br3 = [x + barWidth for x in br2]
br4 = [x + barWidth for x in br3] 
br5 = [x + barWidth for x in br4]
br6 = [x + barWidth for x in br5] 
br7 = [x + barWidth for x in br6]

plt.style.use('seaborn-v0_8')

# Make the plot
plt.bar(br1, N_18_combined, color='tab:blue', width = barWidth, edgecolor ='grey', label ='N = 18') 
plt.bar(br2, N_30_combined, color='tab:green', width = barWidth, edgecolor ='grey', label ='N = 30') 
plt.bar(br3, N_42_combined, color='tab:red', width = barWidth, edgecolor ='grey', label ='N = 42') 
plt.bar(br4, N_54_combined, color='tab:purple', width = barWidth, edgecolor ='grey', label ='N = 54') 
plt.bar(br5, N_66_combined, color='tab:orange', width = barWidth, edgecolor ='grey', label ='N = 66')
plt.bar(br6, N_78_combined, color='tab:olive', width = barWidth, edgecolor ='grey', label ='N = 78') 
plt.bar(br7, N_90_combined, color='tab:brown', width = barWidth, edgecolor ='grey', label ='N = 90')

plt.yscale('log')
plt.ylim(top=1000000000)
plt.xticks([r + barWidth for r in range(len(N_18_combined))], [1,2,3,4], fontsize=18)
plt.yticks(fontsize=18)
plt.xlabel('$\u03C1$', weight='bold', fontsize=18)
plt.ylabel("$\Delta$ Overhead", weight='bold', fontsize=18)
plt.title("Overhead difference for different node populations N", weight='bold', fontsize=14)

legend = plt.legend(loc='upper center', frameon=True, framealpha=1, facecolor='white', fontsize = 14)

# %%
# Time used to find routes IARP and IERP combined

zone_radius = [2,3,4]
N_66_combined = [14710, 70469, 686648]              # FIX DETTE 
N_78_combined = [551945, 173102, 2166647]
N_90_combined = [1243071, 182454, 3597334]

# set width of bar 
barWidth = 0.10

# Set position of bar on X axis 
br1 = np.arange(len(N_66_combined))
br2 = [x + barWidth for x in br1] 
br3 = [x + barWidth for x in br2]

plt.style.use('seaborn-v0_8')

# Make the plot
plt.bar(br1, N_66_combined, color='tab:orange', width = barWidth, edgecolor ='grey', label ='N = 66')
plt.bar(br2, N_78_combined, color='tab:olive', width = barWidth, edgecolor ='grey', label ='N = 78') 
plt.bar(br3, N_90_combined, color='tab:brown', width = barWidth, edgecolor ='grey', label ='N = 90')

plt.yscale('log')
plt.ylim(top=10000000)
plt.xticks([r + barWidth for r in range(len(N_66_combined))], [2,3,4], fontsize=18)
plt.yticks(fontsize=18)
plt.xlabel('$\u03C1$', weight='bold', fontsize=18)
plt.ylabel("$\Delta$ Overhead", weight='bold', fontsize=18)
plt.title("Overhead difference with LOS = 4000", weight='bold', fontsize=14)

legend = plt.legend(loc='upper center', frameon=True, framealpha=1, facecolor='white', fontsize = 14)

# %%
# Specify the CSV file path
csv_file_path = '/Users/mathiasmagnusson/Desktop/etx-vs-pdr.csv'

# Read data from the CSV file
with open(csv_file_path, 'r') as csv_file:
    # Create a CSV reader object
    csv_reader = csv.reader(csv_file)

    # Skip the header if it exists
    header = next(csv_reader)

    # Read x and y values
    x_values = []
    y_values = []
    for row in csv_reader:
        x, y = map(float, row)
        x_values.append(x)
        y_values.append(y)

plt.style.use('seaborn-v0_8')

plt.plot(x_values, y_values, linestyle='-', color='tab:blue', label='PDR', linewidth='3')

plt.yticks(fontsize=12)

plt.xlabel('Expected Transmission Count', weight='bold', fontsize=12)
plt.ylabel('Packet Delivery Ratio (%)', weight='bold', fontsize=12)
plt.title('Packet Delivery Ratio as function of ETX', weight='bold')
legend = plt.legend(loc='upper right', bbox_to_anchor=(0.98, 0.98), frameon=True, framealpha=1, facecolor='white', fontsize = 14)

# %%
# Average ETX

zone_radius = [1,2,3,4,5]
h_518 = [25.49, 27.09, 18.27, 34.54, 42.18]
h_618 = [30.16, 11.24, 22.5, 21.47, 17.36]
h_718 = [26.52, 14.98, 11.15, 17.06, 12.43]
h_818 = [9.89, 4.91, 12.26, 8.49, 9.77]
h_918 = [7.03, 4.82, 5.58, 6.62, 7.1]

# set width of bar 
barWidth = 0.15

# Set position of bar on X axis 
br1 = np.arange(len(h_518))
br2 = [x + barWidth for x in br1] 
br3 = [x + barWidth for x in br2]
br4 = [x + barWidth for x in br3] 
br5 = [x + barWidth for x in br4]

plt.style.use('seaborn-v0_8')

# Make the plot
plt.bar(br1, h_518, color='tab:blue', width = barWidth, edgecolor ='grey', label ='h = 518') 
plt.bar(br2, h_618, color='tab:green', width = barWidth, edgecolor ='grey', label ='h = 618') 
plt.bar(br3, h_718, color='tab:red', width = barWidth, edgecolor ='grey', label ='h = 718') 
plt.bar(br4, h_818, color='tab:purple', width = barWidth, edgecolor ='grey', label ='h = 818') 
plt.bar(br5, h_918, color='tab:orange', width = barWidth, edgecolor ='grey', label ='h = 918')

#plt.yscale('log')
#plt.ylim(top=1000000000)
plt.xticks([r + barWidth for r in range(len(h_518))], [1,2,3,4,5], fontsize=18)
plt.yticks(fontsize=18)
plt.xlabel('Route #', weight='bold', fontsize=18)
plt.ylabel("ETX", weight='bold', fontsize=18)
plt.title("Average ETX for different routes and altitudes", weight='bold', fontsize=14)

legend = plt.legend(loc='upper center', frameon=True, framealpha=1, facecolor='white', fontsize = 14)

# %%
# Time used to find routes IARP and IERP combined

import matplotlib.pyplot as plt

fig, ax = plt.subplots()

Altitude = ['518', '618', '718', '818', '918']
counts = [29.514, 20.546, 16.428, 9.064, 6.23]
bar_labels = ['h = 518', 'h = 618', 'h = 718', 'h = 818', 'h = 918']
bar_colors = ['tab:blue', 'tab:green', 'tab:red', 'tab:purple', 'tab:orange']

ax.bar(Altitude, counts, label=bar_labels, color=bar_colors)

ax.set_ylabel('ETX', weight='bold', fontsize=18)
ax.set_xlabel('Altitude', weight='bold', fontsize=18)
ax.set_title('Average ETX for different altitudes')
#ax.legend(loc='upper right', bbox_to_anchor=(0.98, 0.98), frameon=True, framealpha=1, facecolor='white', fontsize = 14)

# %%
# SABR memory size

import matplotlib.pyplot as plt

fig, ax = plt.subplots()

Altitude = ['66', '132', '264', '396', '528']
counts = [6.9952, 27.904, 111.54, 250.93, 446.08]
bar_labels = ['N = 66', 'N = 132', 'N = 264', 'N = 396', 'N = 528']
bar_colors = ['tab:blue', 'tab:green', 'tab:red', 'tab:purple', 'tab:orange']

ax.bar(Altitude, counts, label=bar_labels, color=bar_colors)

ax.set_ylabel('Size (MB)', weight='bold', fontsize=14)
ax.set_xlabel('Node population', weight='bold', fontsize=14)
ax.set_title('Memory size of adjacency matrix', weight='bold', fontsize=14)
#ax.legend(loc='upper right', bbox_to_anchor=(0.98, 0.98), frameon=True, framealpha=1, facecolor='white', fontsize = 14)
# Out:
# Text(0.5, 1.0, 'Memory size of adjacency matrix')
